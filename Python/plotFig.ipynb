# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
d = pd.read_excel('/Users/cameronrichardson/Documents/Thesis/Code/02102025titration_master copy.xlsx', sheet_name='EXPORT')
# Out:
#          BATCHID   METHOD  SALINITY       PK1       PK2
# 0     AUTO_SAL35     AUTO        35  5.875567  9.028328
# 1     AUTO_SAL35     AUTO        35  5.891443  9.069045
# 2     AUTO_SAL35     AUTO        35  5.869208  8.995413
# 3     AUTO_SAL35     AUTO        35  5.935637  8.904524
# 4     AUTO_SAL28     AUTO        28  5.922074  9.010675
# 5     AUTO_SAL28     AUTO        28  5.846341  9.091961
# 6     AUTO_SAL28     AUTO        28  5.844815  9.141217
# 7     AUTO_SAL28     AUTO        28  5.904435  9.075488
# 8            NaN     AUTO        21       NaN       NaN
# 9            NaN     AUTO        21       NaN       NaN
# 10           NaN     AUTO        21       NaN       NaN
# 11           NaN     AUTO        21       NaN       NaN
# 12          BP15      MAN        35  5.852904  8.969851
# 13          BP15      MAN        35  5.882553  9.027550
# 14          BP15      MAN        35  5.866445  9.027911
# 15          BP15      MAN        35  5.869938  9.029064
# ...
